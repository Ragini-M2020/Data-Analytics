# %%
import pandas as pd

# %%
df=pd.read_csv('/content/sample_data/Batsman.csv')
df
# Out:
#      RunsScored  BallsFaced  BattingPosition Dismissal  Inning   Opposition  \
# 0            12          22                2       LBW       1    Sri Lanka
# 1            37          67                2    Caught       2    Sri Lanka
# 2            25          38                1   Run out       1    Sri Lanka
# 3            54          66                1    Bowled       1    Sri Lanka
# 4            31          46                1       LBW       2    Sri Lanka
# ..          ...         ...              ...       ...     ...          ...
# 203         140         107                3   Stumped       2  West Indies
# 204         157         129                3        NO       1  West Indies
# 205         107         119                3    Bowled       2  West Indies
# 206          16          17                3    Caught       1  West Indies
# 207          33          29                3        NO       2  West Indies
#
#      Year
# 0    2008
# 1    2008
# 2    2008
# ...

# %% [markdown]
# Q-1: Against which team Virat has scored maximum runs?

# %%
df.groupby(['Opposition'])['RunsScored'].sum().sort_values(ascending=False).head(1)
# Out:
# Opposition
# Sri Lanka    2186
# Name: RunsScored, dtype: int64

# %% [markdown]
# Q-2: Show the average score of Virat against each opposition team.

# %%
df.groupby(['Opposition'])['RunsScored'].mean().sort_values(ascending=False)
# Out:
# Opposition
# New Zealand     60.736842
# Bangladesh      59.454545
# West Indies     57.500000
# South Africa    52.875000
# Sri Lanka       48.577778
# Australia       45.461538
# Zimbabwe        42.166667
# Ireland         39.000000
# England         38.344828
# Pakistan        38.250000
# U.A.E.          33.000000
# Netherlands     12.000000
# Name: RunsScored, dtype: float64

# %% [markdown]
# Q-3: Against which team Virat has scored the maximum runs in single inning?

# %%
df['RunsScored'].max()
# Out:
# 183

# %%
df[df['RunsScored']==183]
# Out:
#     RunsScored  BallsFaced  BattingPosition Dismissal  Inning Opposition  Year
# 81         183         148                3    Caught       2   Pakistan  2012

# %%
df[df['RunsScored']==df['RunsScored'].max()].head(1)['Opposition']
# Out:
# 81    Pakistan
# Name: Opposition, dtype: object

# %% [markdown]
# Q-4: In which year, Virat has scored maximum Runs.

# %%
df.groupby(['Year'])['RunsScored'].sum().sort_values(ascending=False).head(1)
# Out:
# Year
# 2017    1460
# Name: RunsScored, dtype: int64

# %% [markdown]
# Q-5: In which year, Virat has scored min Runs.

# %%
df.groupby(['Year'])['RunsScored'].sum().sort_values(ascending=True).head(1)
# Out:
# Year
# 2008    159
# Name: RunsScored, dtype: int64

# %% [markdown]
# Q-6: In which year, Virat has scored maximum Runs with which opposition?

# %%
df.groupby(['Year','Opposition']).RunsScored.sum().sort_values(ascending=False).head(1)
# Out:
# Year  Opposition
# 2012  Sri Lanka     695
# Name: RunsScored, dtype: int64

# %% [markdown]
# Q-7: In how many macthes Virat was not out?

# %%
df[df['Dismissal']=='NO'].count().loc['Dismissal']
# Out:
# 37

# %%
df['Dismissal'].value_counts()
# Out:
# Caught        121
# NO             37
# Bowled         21
# LBW            12
# Run out        12
# Stumped         4
# Hit wicket      1
# Name: Dismissal, dtype: int64

# %% [markdown]
# Q-8: What is Virat Not Out Percentage in the given dataset?

# %%
(df[df['Dismissal']=='NO'].count().loc['Dismissal']/df['Dismissal'].value_counts().sum())*100
# Out:
# 17.78846153846154
