# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('/content/sample_data/credit card.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         30000 non-null  int64
#  1   LIMIT_BAL  30000 non-null  int64
#  2   GENDER     30000 non-null  int64
#  3   EDUCATION  30000 non-null  int64
#  4   MARRIAGE   30000 non-null  int64
#  5   AGE        29990 non-null  float64
#  6   PAY_1      30000 non-null  int64
#  7   PAY_2      30000 non-null  int64
#  8   PAY_3      30000 non-null  int64
#  9   PAY_4      30000 non-null  int64
#  10  PAY_5      30000 non-null  int64
#  11  PAY_6      30000 non-null  int64
#  12  BILL_AMT1  30000 non-null  int64
#  13  BILL_AMT2  30000 non-null  int64
#  14  BILL_AMT3  30000 non-null  int64
#  15  BILL_AMT4  30000 non-null  int64
#  16  BILL_AMT5  30000 non-null  int64
#  17  BILL_AMT6  30000 non-null  int64
#  18  PAY_AMT1   30000 non-null  int64
#  19  PAY_AMT2   30000 non-null  int64
# ...

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  GENDER  EDUCATION  MARRIAGE   AGE  PAY_1  PAY_2  PAY_3  \
# 0   1      20000       2          2         1  24.0      2      2     -1
# 1   2     120000       2          2         2  26.0     -1      2      0
# 2   3      90000       2          2         2  34.0      0      0      0
# 3   4      50000       2          2         1  37.0      0      0      0
# 4   5      50000       1          2         1  57.0     -1      0     -1
#
#    PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -1  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# ...

# %%
# population
# sample

# %%
df.shape
# Out:
# (30000, 25)

# %%
dup=df.duplicated()
dup.sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         30000 non-null  int64
#  1   LIMIT_BAL  30000 non-null  int64
#  2   GENDER     30000 non-null  int64
#  3   EDUCATION  30000 non-null  int64
#  4   MARRIAGE   30000 non-null  int64
#  5   AGE        29990 non-null  float64
#  6   PAY_1      30000 non-null  int64
#  7   PAY_2      30000 non-null  int64
#  8   PAY_3      30000 non-null  int64
#  9   PAY_4      30000 non-null  int64
#  10  PAY_5      30000 non-null  int64
#  11  PAY_6      30000 non-null  int64
#  12  BILL_AMT1  30000 non-null  int64
#  13  BILL_AMT2  30000 non-null  int64
#  14  BILL_AMT3  30000 non-null  int64
#  15  BILL_AMT4  30000 non-null  int64
#  16  BILL_AMT5  30000 non-null  int64
#  17  BILL_AMT6  30000 non-null  int64
#  18  PAY_AMT1   30000 non-null  int64
#  19  PAY_AMT2   30000 non-null  int64
# ...

# %%
df.describe(include='all').T
# Out:
#              count           mean            std       min       25%  \
# ID         30000.0   15000.500000    8660.398374       1.0   7500.75
# LIMIT_BAL  30000.0  167484.322667  129747.661567   10000.0  50000.00
# GENDER     30000.0       1.603733       0.489129       1.0      1.00
# EDUCATION  30000.0       1.853133       0.790349       0.0      1.00
# MARRIAGE   30000.0       1.551867       0.521970       0.0      1.00
# AGE        29990.0      35.487062       9.236845     -20.0     28.00
# PAY_1      30000.0      -0.016700       1.123802      -2.0     -1.00
# PAY_2      30000.0      -0.133767       1.197186      -2.0     -1.00
# PAY_3      30000.0      -0.166200       1.196868      -2.0     -1.00
# PAY_4      30000.0      -0.220667       1.169139      -2.0     -1.00
# PAY_5      30000.0      -0.266200       1.133187      -2.0     -1.00
# PAY_6      30000.0      -0.291100       1.149988      -2.0     -1.00
# BILL_AMT1  30000.0   51223.330900   73635.860576 -165580.0   3558.75
# ...

# %% [markdown]
# 1. univariate analysis
# 2. bivariate analysis
# 3. treatment of missing values
# 4. treatment of bad values
# 5. change data types
# 6. Data encoding
# 7. scaling

# %%
#checking the missing values in dataset
df.isnull().sum()

# %%
#checking the data for missing Ages
df[df.AGE.isnull()]
# Out:
#           ID  LIMIT_BAL  GENDER  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  \
# 5          6      50000       1          1         2  NaN      0      0
# 21        22     120000       2          2         1  NaN     -1     -1
# 31        32      50000       1          2         2  NaN      2      0
# 63        64      50000       2          2         1  NaN      0      0
# 3110    3111     100000       1          2         1  NaN      0      0
# 3118    3119      60000       2          2         1  NaN      0      0
# 3199    3200     180000       1          2         2  NaN      1     -2
# 3216    3217      20000       2          1         2  NaN      2      2
# 10705  10706      20000       2          2         2  NaN      0      0
# 10716  10717     280000       1          2         2  NaN     -1     -1
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 5          0      0  ...      19394      19619      20024      2500      1815
# ...

# %%
# imputing the null values in age with mean
df.AGE=df.AGE.fillna(df.AGE.mean())
df[df.AGE.isnull()]

# %%
# Anamolies
df.describe(include='all').T

# %%
sns.boxplot(x='AGE',data=df)
# Out:
# <Axes: xlabel='AGE'>

# %%
df[df.AGE<18]
# Out:
#       ID  LIMIT_BAL  GENDER  EDUCATION  MARRIAGE   AGE  PAY_1  PAY_2  PAY_3  \
# 409  410     280000       1          1         2 -20.0      0      0      0
#
#      PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 409      0  ...     182672     168399     167983     10000      8000
#
#      PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# 409      6371      6217      5947      6288        0
#
# [1 rows x 25 columns]

# %%
df[df.AGE>80]
# Out:
#       ID  LIMIT_BAL  GENDER  EDUCATION  MARRIAGE    AGE  PAY_1  PAY_2  PAY_3  \
# 430  431      90000       2          2         2  120.0      0      0      0
#
#      PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 430      0  ...      74424      76070      77648      3200      3300
#
#      PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# 430      3000      3001      3000      3100        0
#
# [1 rows x 25 columns]

# %%
#replacing the outliers record of age withe mean value
df.AGE.replace(to_replace=-20,value=df.AGE.mean(),inplace=True)

# %%
df.AGE.replace(to_replace=120,value=df.AGE.mean(),inplace=True)

# %%
df.AGE.describe()
# Out:
# count    30000.000000
# mean        35.486095
# std          9.216840
# min         21.000000
# 25%         28.000000
# 50%         34.000000
# 75%         41.000000
# max         79.000000
# Name: AGE, dtype: float64

# %%
# for pay column
#if value is -2 then no consumption
#if value is -1 then fully paid
# if value is 0 then revolving credit
# if value is 1 to 9 then payment is delay by 1 month..upto 9 month

# %%
# for gender column
# 1 is for male
# 2 is for female

# %%
# for marriage
# 1 is for married
# 2 is for single
# 3 is for others

# %%
# for education
# 1 is for graduate
# 2 is for university
# 3 is for high school
# 4 is for others
# 5&6 is for unknown

# %%
# q1 Are married customers becoming defaulter due to increased family responsibilties?
# q2 Are young customers taking advantage of credits limit but not paying back?
# q3 Are customers with lower education level not able to pack back ?
# q4 Are customers with higher credit limit not able to pack back?
# q5  Are males more defaulter than females?
# q6 Are Customers using revolving credit tends to reach credit limit?

# %%
# population inference
# 1. You again find yourself as plant operations manager for Oxford Cereals. You are responsible for monitoring the amount in each cereal box filled.
# Company specifications require a mean weight of 368 grams per box.
#It is your responsibility to adjust the process when the mean fill weight in the population of boxes deviates from 368 grams.
#How can you rationally make the decision whether or not to adjust the process when it is impossible to weigh every single box as it is being filled?
# You begin by selecting and weighing a random sample of 25 cereal boxes. After computing a sample mean, how do you proceed?
